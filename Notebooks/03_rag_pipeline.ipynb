# %%
import os, faiss, pickle
import numpy as np
from sentence_transformers import SentenceTransformer
from dotenv import load_dotenv
from huggingface_hub import login

# %%
FAISS_INDEX_PATH = "../data/embeddings/faiss_index.bin"
METADATA_PATH = "../data/embeddings/metadata.pkl"
PDF_DIR = "../data/raw_pdfs"

load_dotenv(dotenv_path='../Secrets/.env')

login(token=os.environ['HF_TOKEN'])
# Out:
# Note: Environment variable`HF_TOKEN` is set and is the current active token independently from the token you've just configured.

# %%
# Load FAISS index
index = faiss.read_index(FAISS_INDEX_PATH)

# Load metadata
with open(METADATA_PATH, "rb") as f:
    metadata = pickle.load(f)
print(f"Loaded index with {index.ntotal} entries.")
# Out:
# Loaded index with 13895 entries.

# %%
embed_model = SentenceTransformer("sentence-transformers/all-MiniLM-L6-v2")

# %%
def retrieve_top_k(query, k=5, similarity_threshold=0):
    """
    Retrieve top-k relevant chunks from FAISS, grouped by page with snapshots & images.
    Apply similarity threshold to filter noisy matches.
    """

    # Encode query
    query_vec = embed_model.encode([query], convert_to_numpy=True)

    # Search FAISS index
    distances, indices = index.search(query_vec, k)

    # Convert L2 distance to cosine-like similarity (optional, depends on index type)
    # For IndexFlatL2: lower distance = better, so invert to similarity
    max_dist = np.max(distances)
    similarities = 1 - (distances / max_dist)

    # Step 1: Collect raw results (with threshold filtering)
    raw_results = []
    for idx, dist, sim in zip(indices[0], distances[0], similarities[0]):
        if idx == -1:
            continue
        if sim < similarity_threshold:   # skip low-similarity chunks
            continue

        chunk_meta = metadata[idx]
        raw_results.append({
            "content": chunk_meta["content"],
            "page_num": chunk_meta["page_num"],
            "pdf_file": chunk_meta["pdf_file"],
            "page_snapshot": chunk_meta.get("page_snapshot"),
            "images": chunk_meta.get("images", []),
            "captions": chunk_meta.get("captions", []),
            "distance": float(dist),
            "similarity": float(sim),
            "link": f"{PDF_DIR}/{chunk_meta['pdf_file']}#page={chunk_meta['page_num']}",
        })

    # Step 2: Group by page
    grouped = {}
    for r in raw_results:
        page = r["page_num"]
        if page not in grouped:
            grouped[page] = {
                "page_num": page,
                "pdf_file": r["pdf_file"],
                "content": [],
                "images": [],
                "captions": r.get("captions", []),
                "page_snapshot": r["page_snapshot"],
                "link": r["link"]
            }
        grouped[page]["content"].append(r["content"])
        grouped[page]["images"].extend(r["images"])

    # Step 3: Merge
    results = []
    for page, data in grouped.items():
        merged_text = " ".join(data["content"])
        snippet = merged_text[:150] + "..." if len(merged_text) > 150 else merged_text
        results.append({
            "page_num": page,
            "pdf_file": data["pdf_file"],
            "content": merged_text,
            "page_snapshot": data["page_snapshot"],
            "images": list(set(data["images"])),
            "captions": data.get("captions", []),
            "link": data["link"],
            "snippet": snippet
        })

    return sorted(results, key=lambda x: x["page_num"])

# %%
from numpy.linalg import norm

def filter_images_by_caption_similarity(query, captions, threshold=0.1):
    """
    Return only images whose caption similarity with query exceeds threshold.
    """
    # Encode query
    query_emb = embed_model.encode([query], convert_to_numpy=True)[0]
    relevant_images = []

    for cap in captions:
        if cap.get("embedding") is not None:
            cap_emb = np.array(cap["embedding"])
            sim = np.dot(query_emb, cap_emb) / (norm(query_emb) * norm(cap_emb))
            if sim >= threshold:
                relevant_images.append(cap["image_path"])
    return relevant_images

# %%
from huggingface_hub import InferenceClient
import os

# Initialize client
client = InferenceClient(
    provider="auto",
    timeout=400,
)


def generate_answer_multimodal(query, retrieved_chunks, model="unsloth/Mistral-Small-3.2-24B-Instruct-2506-GGUF"):
    """
    Generate structured answer (Definition, Causes, Diagnosis, Treatment) using text + images.
    """

    # Combine retrieved text context
    context_text = "\n\n".join([
        f"--- Page {c['page_num']} ---\nText:\n{c['content']}"
        for c in retrieved_chunks
    ])

    print(context_text)

    # Collect relevant image paths (page snapshots + extracted images)
    image_paths = []
    for c in retrieved_chunks:
        if c.get("page_snapshot"):
            image_paths.append(c["page_snapshot"])
        image_paths.extend(c.get("images", []))

    system_prompt = """
You are a knowledgeable medical assistant.

- Use ONLY the provided context (text) to answer the user query.
- Output strictly in English.
- If specific sections like Definition, Causes, Diagnosis, or Treatment are relevant, organize the answer using these sections.
- If the query does not fit these sections (e.g., a simple definition or general explanation), provide a concise, well-structured paragraph instead.
- If any requested information is missing in the context, explicitly state "Not mentioned in the document."
- Do NOT invent facts, add unrelated metadata, or include random symbols.
- Do NOT mention images unless explicitly described in the text.
- If you need to say about document then say According to my sources.

For structured answers (when applicable), use this format:

**Definition:**
<text>

**Causes:**
<text>

**Diagnosis:**
<text>

**Treatment:**
<text>

For general answers (when structured sections are irrelevant), provide a single detailed paragraph addressing the query clearly and factually and in detail.

For Example:
Query:
What is asthma and how is it diagnosed?

Answer:
**Definition:**
Asthma is a chronic inflammatory disease of the airways characterized by episodes of wheezing and breathlessness.

**Causes:**
- Allergic reactions
- Environmental triggers
- Respiratory infections

**Diagnosis:**
- Spirometry
- Peak flow measurement

**Treatment:**
- Inhaled corticosteroids
- Bronchodilators

For Example:
Query:
What is antigen?

Answer:
An Antigen (Ag) is a molecule, moiety, foreign particulate matter, or an allergen, such as pollen, that can bind to a specific antibody or T-cell receptor. The presence of antigens in the body may trigger an immune response.
Antigens can be proteins, peptides (amino acid chains), polysaccharides (chains of simple sugars), lipids, or nucleic acids.[3][4] Antigens exist on normal cells, cancer cells, parasites, viruses, fungi, and bacteria.

"""

    # ---- User Prompt ----
    user_prompt = f"""
Context:
{context_text}

User Question:
{query}
"""

    # Prepare messages for API
    messages = [
        {"role": "system", "content": [{"type": "text", "text": system_prompt}]},
        {"role": "user", "content": [{"type": "text", "text": user_prompt}]}
    ]

    # Attach images as multimodal content
    # for img_path in image_paths:
    #     if os.path.exists(img_path):
    #         messages[0]["content"].append({"type": "image", "image": img_path})

    # Call API (non-streaming to avoid timeout issues)
    response = client.chat.completions.create(
        model=model,
        messages=messages,
        stream=False,
        max_tokens=1000
    )

    # Extract text output
    answer = response.choices[0].message["content"]
    return answer

def rag_query_multimodal(query, k=5):
    """Retrieve text + images, generate multimodal structured answer."""
    # Retrieve top-k chunks (text + metadata)
    retrieved = retrieve_top_k(query, k=k)

    # Generate answer with text + image context
    answer = generate_answer_multimodal(query, retrieved, 
                                        model="google/gemma-3-27b-it"
                                        )

    # Prepare references with page, snapshots, images (caption-aware)
    references = []
    for r in retrieved:
        # Filter images by caption similarity
        relevant_images = filter_images_by_caption_similarity(
            query,
            r.get("captions", []),
            threshold=0.4
        )

        references.append({
            "page": r["page_num"],
            "link": r["link"],
            "snippet": r["snippet"],
            "page_snapshot": r.get("page_snapshot"),
            "images": relevant_images  # only relevant images
        })
    
    return answer, references

query1 = "What are the causes and treatment for Atherosclerosis in detail?"
query2 = "What is Hypertension?"
query3 = "What is Alkaline phosphatase test?"
query4 = "What is Hemoglobin?"
query5 = "How to cure Diabetes?"
query6 = "What is Hernia?"
answer, references = rag_query_multimodal(query4, k=50)

print("### Answer ###\n", answer)
print("\n### References ###")
for ref in references:
    print(f"- Page {ref['page']}: {ref['link']} ({ref['snippet']})")
    print(f"  Page Snapshot: {ref['page_snapshot']}")
    if ref['images']:
        print(f"  Images: {', '.join(ref['images'])}")
# Out:
# c:\Users\Asus\Downloads\Medical Bot\.venv\Lib\site-packages\torch\nn\modules\module.py:1762: FutureWarning: `encoder_attention_mask` is deprecated and will be removed in version 4.55.0 for `BertSdpaSelfAttention.forward`.
#   return forward_call(*args, **kwargs)
# --- Page 103 ---
# Text:
# They carry one gene for albinism.
#
# --- Page 120 ---
# Text:
# Sandra Bain Cushman Alkali-resistant hemoglobin test see Fetal hemoglobin test Alkaline phosphatase test Definition Alkaline phosphatase is an enzyme found throughout the body.
#
# --- Page 147 ---
# Text:
# This is known as hypoxemia.
#
# --- Page 195 ---
# Text:
# (Hemoglobin is composed of four chains of amino acids.) HEMOLYTIC ANEMIA. An inherited form of hemolytic anemia, thalassemia stems from the body s inability to manufacture as much normal hemoglobin as it needs. Some people are born with hemolytic anemia . Hemolytic anemia can enlarge the spleen, accelerating the destruction of red blood cells (hemolysis). AUTOIMMUNE HEMOLYTIC ANEMIAS. Warm antibody hemolytic anemia is the most common type of this disorder. In cold antibody hemolytic anemia, the body attacks red blood cells at or below normal body temperature.
#
# --- Page 196 ---
# Text:
# Sickle cell anemia is a chronic, incurable condition that causes the body to produce defective hemoglobin, which forces red blood cells to assume an abnormal crescent shape. Unlike normal oval cells, fragile sickle cells cannot hold enough hemoglobin to nourish body tissues. SICKLE CELL ANEMIA.
#
# --- Page 197 ---
# Text:
# HEMOLYTIC ANEMIA. Laboratory tests that measure the percentage of red blood cells or the amount of hemoglobin in the blood are used to confirm diagnosis and determine which type of anemia is responsible for a patient s symptoms. SICKLE CELL ANEMIA. ANEMIA OF CHRONIC DISEASE. This operation controls anemia in about half of the patients on whom it is performed.
#
# --- Page 199 ---
# Text:
# Hemolytic anemia Acquired hemolytic anemia can generally be cured when the because is removed.
#
# --- Page 264 ---
# Text:
# Inhibitors of thrombin.
#
# --- Page 351 ---
# Text:
# Cells called reticulocytes (very young red blood cells, which are usually produced in great numbers by the bone marrow in order to compensate for a severe anemia) will be very low in number.
#
# --- Page 386 ---
# Text:
# in blood plasma.
#
# --- Page 436 ---
# Text:
# Autoimmune hemolytic anemia . Occurs when the body produces antibodies that coat red blood cells.
#
# --- Page 437 ---
# Text:
# Autoimmune hemolytic anemia.
#
# --- Page 466 ---
# Text:
# In the process, up to 90% of the host s erythrocytes are destroyed, causing severe hemolytic anemia.
#
# --- Page 533 ---
# Text:
# In a rare complication, called retrobulbar hematoma, a pocket of blood forms behind the eyeball.
#
# --- Page 535 ---
# Text:
# Hemoglobin (Hgb) is the protein-iron compound in the red blood cells that enables them to transport oxygen. Also closely tied to the RBC and hemoglobin values is the hematocrit (Hct), which measures the percentage of red blood cells in the total blood volume. The hematocrit (expressed as percentage points) is normally about three times the hemoglobin concentration (reported as grams per deciliter). The indices include four measurements that are calculated using the RBC count, hemoglobin, and hematocrit results. Mean corpuscular hemoglobin (MCH) measures the average amount (weight) of hemoglobin within a red blood cell. Red blood cell indices provide information about the size and hemoglobin content of the red cells. A similar measurement, mean corpuscular hemoglobin concentration (MCHC), expresses the average concentration of hemoglobin in the red blood cells. Components of the complete blood count (hemoglobin, hematocrit, white blood cells, platelets, etc.) They are useful in differentiating types of anemias.
#
# --- Page 536 ---
# Text:
# Hemoglobin values range from 14 18 grams per deciliter of blood for men and 12 16 grams for women. One of the most common is anemias, which are characterized by low RBC counts, hemoglobins, and hematocrits. The normal hematocrit is 42 54% for men and 36 48% for women.
#
# --- Page 539 ---
# Text:
# Red blood cells, which carry oxygen, are used to treat anemia.
#
# --- Page 541 ---
# Text:
# The remainder of oxygen that is not dissolved in the blood combines with hemoglobin, a protein iron compound found in the red blood cells. A related value is the oxygen saturation, which compares the amount of oxygen actually combined with hemoglobin to the total amount of oxygen that the hemoglobin is capable of combining with. The oxygen content measurement in an ABG analysis indicates how much oxygen is combined with the hemoglobin. It measures the partial pressures of oxygen and carbon dioxide in the blood, as well as oxygen content, oxygen saturation, bicarbonate content, and blood pH.
#
# --- Page 545 ---
# Text:
# Blood typing ABO BLOOD GROUP SYSTEM. Parents who are expecting a baby have their blood typed to diagnose and prevent hemolytic disease of the newborn (HDN), a type of anemia also known as erythroblastosis fetalis .
#
# --- Page 549 ---
# Text:
# Description The BUN test is performed on a sample of the patient s blood, withdrawn from a vein into a vacuum tube.
#
# --- Page 564 ---
# Text:
# Under normal circumstances, red blood cells carry oxygen throughout the body and remove carbon dioxide from the body s tissues.
#
# --- Page 622 ---
# Text:
# This is referred to as a hematoma.
# ### Answer ###
#  According to my sources,
#
# Hemoglobin (Hgb) is the protein-iron compound in the red blood cells that enables them to transport oxygen. Hemoglobin values range from 14-18 grams per deciliter of blood for men and 12-16 grams for women. It is composed of four chains of amino acids. It also combines with oxygen, and the oxygen content measurement indicates how much oxygen is combined with the hemoglobin. Different types of hemoglobin exist, including normal hemoglobin and defective hemoglobin (as seen in sickle cell anemia).
#
# ### References ###
# - Page 103: ../data/raw_pdfs/medical_book.pdf#page=103 (They carry one gene for albinism.)
#   Page Snapshot: ../data/page_images/medical_book_page103_snapshot.png
# - Page 120: ../data/raw_pdfs/medical_book.pdf#page=120 (Sandra Bain Cushman Alkali-resistant hemoglobin test see Fetal hemoglobin test Alkaline phosphatase test Definition Alkaline phosphatase is an enzyme ...)
#   Page Snapshot: ../data/page_images/medical_book_page120_snapshot.png
# - Page 147: ../data/raw_pdfs/medical_book.pdf#page=147 (This is known as hypoxemia.)
#   Page Snapshot: ../data/page_images/medical_book_page147_snapshot.png
# - Page 195: ../data/raw_pdfs/medical_book.pdf#page=195 ((Hemoglobin is composed of four chains of amino acids.) HEMOLYTIC ANEMIA. An inherited form of hemolytic anemia, thalassemia stems from the body s ina...)
#   Page Snapshot: ../data/page_images/medical_book_page195_snapshot.png
# - Page 196: ../data/raw_pdfs/medical_book.pdf#page=196 (Sickle cell anemia is a chronic, incurable condition that causes the body to produce defective hemoglobin, which forces red blood cells to assume an a...)
#   Page Snapshot: ../data/page_images/medical_book_page196_snapshot.png
# - Page 197: ../data/raw_pdfs/medical_book.pdf#page=197 (HEMOLYTIC ANEMIA. Laboratory tests that measure the percentage of red blood cells or the amount of hemoglobin in the blood are used to confirm diagnos...)
#   Page Snapshot: ../data/page_images/medical_book_page197_snapshot.png
#   Images: ../Data/image_with_captions/medical_book_page197_img1.jpeg
# - Page 199: ../data/raw_pdfs/medical_book.pdf#page=199 (Hemolytic anemia Acquired hemolytic anemia can generally be cured when the because is removed.)
#   Page Snapshot: ../data/page_images/medical_book_page199_snapshot.png
# - Page 264: ../data/raw_pdfs/medical_book.pdf#page=264 (Inhibitors of thrombin.)
#   Page Snapshot: ../data/page_images/medical_book_page264_snapshot.png
# - Page 351: ../data/raw_pdfs/medical_book.pdf#page=351 (Cells called reticulocytes (very young red blood cells, which are usually produced in great numbers by the bone marrow in order to compensate for a se...)
#   Page Snapshot: ../data/page_images/medical_book_page351_snapshot.png
# - Page 386: ../data/raw_pdfs/medical_book.pdf#page=386 (in blood plasma.)
#   Page Snapshot: ../data/page_images/medical_book_page386_snapshot.png
# - Page 436: ../data/raw_pdfs/medical_book.pdf#page=436 (Autoimmune hemolytic anemia . Occurs when the body produces antibodies that coat red blood cells.)
#   Page Snapshot: ../data/page_images/medical_book_page436_snapshot.png
# - Page 437: ../data/raw_pdfs/medical_book.pdf#page=437 (Autoimmune hemolytic anemia.)
#   Page Snapshot: ../data/page_images/medical_book_page437_snapshot.png
# - Page 466: ../data/raw_pdfs/medical_book.pdf#page=466 (In the process, up to 90% of the host s erythrocytes are destroyed, causing severe hemolytic anemia.)
#   Page Snapshot: ../data/page_images/medical_book_page466_snapshot.png
# - Page 533: ../data/raw_pdfs/medical_book.pdf#page=533 (In a rare complication, called retrobulbar hematoma, a pocket of blood forms behind the eyeball.)
#   Page Snapshot: ../data/page_images/medical_book_page533_snapshot.png
# - Page 535: ../data/raw_pdfs/medical_book.pdf#page=535 (Hemoglobin (Hgb) is the protein-iron compound in the red blood cells that enables them to transport oxygen. Also closely tied to the RBC and hemoglobi...)
#   Page Snapshot: ../data/page_images/medical_book_page535_snapshot.png
#   Images: ../Data/image_with_captions/medical_book_page535_img1.jpeg
# - Page 536: ../data/raw_pdfs/medical_book.pdf#page=536 (Hemoglobin values range from 14 18 grams per deciliter of blood for men and 12 16 grams for women. One of the most common is anemias, which are charac...)
#   Page Snapshot: ../data/page_images/medical_book_page536_snapshot.png
# - Page 539: ../data/raw_pdfs/medical_book.pdf#page=539 (Red blood cells, which carry oxygen, are used to treat anemia.)
#   Page Snapshot: ../data/page_images/medical_book_page539_snapshot.png
# - Page 541: ../data/raw_pdfs/medical_book.pdf#page=541 (The remainder of oxygen that is not dissolved in the blood combines with hemoglobin, a protein iron compound found in the red blood cells. A related v...)
#   Page Snapshot: ../data/page_images/medical_book_page541_snapshot.png
# - Page 545: ../data/raw_pdfs/medical_book.pdf#page=545 (Blood typing ABO BLOOD GROUP SYSTEM. Parents who are expecting a baby have their blood typed to diagnose and prevent hemolytic disease of the newborn ...)
#   Page Snapshot: ../data/page_images/medical_book_page545_snapshot.png
# - Page 549: ../data/raw_pdfs/medical_book.pdf#page=549 (Description The BUN test is performed on a sample of the patient s blood, withdrawn from a vein into a vacuum tube.)
#   Page Snapshot: ../data/page_images/medical_book_page549_snapshot.png
# - Page 564: ../data/raw_pdfs/medical_book.pdf#page=564 (Under normal circumstances, red blood cells carry oxygen throughout the body and remove carbon dioxide from the body s tissues.)
#   Page Snapshot: ../data/page_images/medical_book_page564_snapshot.png
# - Page 622: ../data/raw_pdfs/medical_book.pdf#page=622 (This is referred to as a hematoma.)
#   Page Snapshot: ../data/page_images/medical_book_page622_snapshot.png

# %%
# from PIL import Image
# import matplotlib.pyplot as plt
# import os

# def show_reference_images(references):
#     """
#     Display page snapshots and extracted images from references (non-Streamlit).
#     """

#     for ref in references:
#         page = ref["page"]
#         snapshot = ref.get("page_snapshot")
#         images = ref.get("images", [])

#         print(f"\n--- Page {page} ---")

#         # Show page snapshot if available
#         if snapshot and os.path.exists(snapshot):
#             print(f"Page Snapshot: {snapshot}")
#             img = Image.open(snapshot)
#             plt.figure(figsize=(8, 10))
#             plt.imshow(img)
#             plt.axis("off")
#             plt.title(f"Full Page {page}")
#             plt.show()

#         # Show extracted images (figures/tables)
#         if images:
#             for img_path in images:
#                 if os.path.exists(img_path):
#                     print(f"Extracted Image: {img_path}")
#                     img = Image.open(img_path)
#                     plt.figure(figsize=(6, 6))
#                     plt.imshow(img)
#                     plt.axis("off")
#                     plt.title(f"Figure from Page {page}")
#                     plt.show()

# show_reference_images(references)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[14], line 39
#      36                     plt.title(f"Figure from Page {page}")
#      37                     plt.show()
# ---> 39 show_reference_images(references)
#
# NameError: name 'references' is not defined
